# %%
from textblob import TextBlob
import pandas as pd
pd.set_option('max_colwidth',1000)
import numpy as np
import csv
with open('/Users/Matt/Desktop/Fall2018/HonorsProject/Honors-Master/Data_and_Papers/Data-Gather/positive_data.csv', "wb") as csv_file:writer = csv.writer(csv_file, delimiter=',')

# %%
tweets = pd.DataFrame()
tweets = pd.read_csv( '/Users/Matt/Desktop/Fall2018/HonorsProject/Honors-Master/Data_and_Papers/Unlabeled/270k_unlabeled_format.csv')

sorted_data = open('/Users/Matt/Desktop/Fall2018/HonorsProject/Honors-Master/Data_and_Papers/Data-Gather/positive_data.csv', 'w')
size = 0

for i in range(10):
    tweet = tweets[i:i+1]
    sentence = tweet['tweet'].to_string(header=False, index=False)
    is_positive = TextBlob(sentence)
    is_positive.sentiment
    if is_positive.sentiment.polarity > .7:
        print(' \n')
        #print(tweet['tweet'].to_string(header=False, index=False))
        #sorted_data.write(tweet['user'].to_string(header=False, index=False) + '\t' + tweet['tweet'].to_string(header=False, index=False) + '\n')
    else:
        print(tweet['tweet'].to_string(header=False, index=False))
        print(tweets[i:i+1])
        print(is_positive.sentiment)
        tweets = tweets.drop(i)

#print(tweets)
tweets.to_csv('/Users/Matt/Desktop/Fall2018/HonorsProject/Honors-Master/Data_and_Papers/Data-Gather/positive_data.csv')
sorted_data.close()
# Out:
# Next Day I Off Xanax Life
#         user            tweet_id                      tweet  ade
# 0  351832646  565415996241215000  Next Day I Off Xanax Life  0.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# Adderall and coffee.
#         user            tweet_id                 tweet  ade
# 2  629013191  532597542257954000  Adderall and coffee.  0.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# Just went and copd #NBA2K15
#         user            tweet_id                        tweet  ade
# 4  541294335  536966955623002000  Just went and copd #NBA2K15  0.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# Adderall had me like "my palms are sweaty, knees weak, arms are heavy"â€ - said all the high schoolers during finals
#          user            tweet_id  \
# 6  2329845796  546072108410081000
#
#                                                                                                                    tweet  \
# 6  Adderall had me like "my palms are sweaty, knees weak, arms are heavy"â€ - said all the high schoolers during finals
#
#    ade
# 6  0.0
# Sentiment(polarity=-0.1383333333333333, subjectivity=0.555)
# â€œ@AdderallHadMe: When the Adderall kicks in https://twitter.com/AdderallHadMe/status/540204923363676160/photo/1pic.twitter.com/vGtdL767BnÂ â€ @Stickynipps
#          user            tweet_id  \
# 8  1849663171  545774423983149000
#
#                                                                                                                                                            tweet  \
# 8  â€œ@AdderallHadMe: When the Adderall kicks in https://twitter.com/AdderallHadMe/status/540204923363676160/photo/1pic.twitter.com/vGtdL767BnÂ â€ @Stickynipps
#
#    ade
# 8  0.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# Thalidomide survivors seek more financial support from Ottawa, to know of that which they may not well speak. Some. #XmasListIn3Words
#           user            tweet_id  \
# 10  2791066327  539876694262554000
#
#                                                                                                                                     tweet  \
# 10  Thalidomide survivors seek more financial support from Ottawa, to know of that which they may not well speak. Some. #XmasListIn3Words
#
#     ade
# 10  0.0
# Sentiment(polarity=0.25, subjectivity=0.25)
# First night out in ages and what do I reach for..... Imodium
#          user            tweet_id  \
# 12  408787246  558994875769974000
#
#                                                             tweet  ade
# 12  First night out in ages and what do I reach for..... Imodium   0.0
# Sentiment(polarity=0.25, subjectivity=0.3333333333333333)
# @killuhky amen, xanax is fucking awful
#          user            tweet_id                                   tweet  ade
# 14  473595147  563735596670406000  @killuhky amen, xanax is fucking awful  1.0
# Sentiment(polarity=-1.0, subjectivity=1.0)
# Adderall had me thinking I was an ice road trucker on the way to work.pic.twitter.com/JblHk0F42T
#         user            tweet_id  \
# 16  92137598  562276019286327000
#
#                                                                                                tweet  \
# 16  Adderall had me thinking I was an ice road trucker on the way to work.pic.twitter.com/JblHk0F42T
#
#     ade
# 16  0.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# @iSmashFizzle was on wellbutrin for a while. Couldn't handle vyvanse but my dad is fine on it. Rn=10 mg of adderall as needed
#         user            tweet_id  \
# 18  24580091  528921838576234000
#
#                                                                                                                             tweet  \
# 18  @iSmashFizzle was on wellbutrin for a while. Couldn't handle vyvanse but my dad is fine on it. Rn=10 mg of adderall as needed
#
#     ade
# 18  1.0
# Sentiment(polarity=0.4166666666666667, subjectivity=0.5)
