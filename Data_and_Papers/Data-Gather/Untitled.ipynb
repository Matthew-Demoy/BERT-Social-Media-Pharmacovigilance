# %%
from textblob import TextBlob
import pandas as pd
pd.set_option('max_colwidth',1000)
import numpy as np
import csv
with open('/Users/Matt/Desktop/Fall2018/HonorsProject/Honors-Master/Data_and_Papers/Data-Gather/positive_data.csv', "wb") as csv_file:writer = csv.writer(csv_file, delimiter=',')

# %%
tweets = pd.DataFrame()
tweets = pd.read_csv( '/Users/Matt/Desktop/Fall2018/HonorsProject/Honors-Master/Data_and_Papers/Unlabeled/270k_unlabeled_format.csv')
tweets = tweets.assign()
sorted_data = open('/Users/Matt/Desktop/Fall2018/HonorsProject/Honors-Master/Data_and_Papers/Data-Gather/positive_data.csv', 'w')
i = 1

for i in range(1,1716):
    tweet = tweets[i:i+1]
    sentence = tweet['tweet'].to_string(header=False, index=False)
    is_positive = TextBlob(sentence)
    is_positive.sentiment
    if is_positive.sentiment.polarity < .5:
        #print(tweets[i:i+1])
        #print(is_positive.sentiment)
        tweets = tweets.drop(i)
    else:
        print(tweet['tweet'].to_string(header=False, index=False))
        #print(tweet['tweet'].to_string(header=False, index=False))
        #sorted_data.write(tweet['user'].to_string(header=False, index=False) + '\t' + tweet['tweet'].to_string(header=False, index=False) + '\n')
        

#print(tweets)
tweets.to_csv('/Users/Matt/Desktop/Fall2018/HonorsProject/Honors-Master/Data_and_Papers/Data-Gather/positive_data.csv')
sorted_data.close()
# Out:
# Dear girl in stelara commercial, your perfect
# I've considered taking adderall wayyyy too many times this semester....
# Can my coffee magically turn into adderall
# @Yasowi w Jeep fen :D
# @MRDIZASTER u <3 amphetamines
# Did Nationwide team up with Prozac this year? Why is everyone on my TL talking about them lol?
# NICE risks making itself a 'laughing stock' over guidance on metformin alternatives, say experts
# True! â€œ@IVF_MD: @PCOSGurl @PCOSnutrition @LifeQuestIVF Cheat at your own peril. Metformin will make you pay if you continue to eat carbs.â€
# Being high and on adderall is the greatest thing #soproductive
# Albuterol you my best friend.
# Thinking of crushing adderall into my coffee. It's that kind of day.
# @Estelle_Lucas imodium tablets. Always take them on a trip. Helps if you get the 'runs' :) hope you're feeling better!
# Bout to pop an adderall and watch all 325 minutes of Nymphomaniac, pls do not show this tweet to my therapist and/or loved ones
# â€œ@AdderallHadMe: Adderall had me calculating the lowest grades I can get on my finals instead of studyingâ€ @CaseyKinnie1 lol
# adderall pputs me in great moods hope nobody fucks it up
# â€œ@Gabriela98x3: What's adderall likeâ€ it's really nice
# COLLEGE HOES LOVE ALCHOL AND POPPIN ADDERALL
# @Lillyreyanne @Dory I remember my webkinz password without adderall :-)
